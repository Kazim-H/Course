# %%
n =[]
q1=int(input("Number of elements? (5/6)"))

a=int(input("Enter 1st number: "))
b=int(input("Enter 2nd number: "))
c=int(input("Enter 3rd number: "))
d=int(input("Enter 4th number: "))
e=int(input("Enter 5th number: "))
if q1 == 6:
    f =int(input("Enter 6th number: "))
if a>b and a>c and a>d and a>e:
    n.insert(0,a)
elif b>a and b>c and b>d and b>e:
    n.insert(0,b)
elif c>b and c>a and c>d and c>e:
    n.insert(0,c)
elif d>b and d>c and d>a and d>e:
    n.insert(0,d)
elif e>b and e>c and e>d and e>a:
    n.insert(0,e)
if q1 == 6:
    if f>b and f>c and f>d and f>a:
         n.insert(0,f)
if n[0] == a:
    a = -999
elif n[0] == b:
    b = -999
elif n[0] == c:
    c = -999
elif n[0] == d:
    d = -999
elif n[0] == e:
    e = -999
if a>b and a>c and a>d and a>e:
    n.insert(1,a)
elif b>a and b>c and b>d and b>e:
    n.insert(1,b)
elif c>b and c>a and c>d and c>e:
    n.insert(1,c)
elif d>b and d>c and d>a and d>e:
    n.insert(1,d)
elif e>b and e>c and e>d and e>a:
    n.insert(1,e)
if q1 == 6:
    if n[1] == f:
         f = int(-999)
if q1 == 6:
    if f>b and f>c and f>d and f>a:
        n.insert(1,f)
if n[1] == a:
    a = int(-999)
elif n[1] == b:
    b = int(-999)
elif n[1] == c:
    c = int(-999)
elif n[1] == d:
    d = int(-999)
elif n[1] == e:
    e = int(-999)
if a>b and a>c and a>d and a>e:
    n.insert(2,a)
elif b>a and b>c and b>d and b>e:
    n.insert(2,b)
elif c>b and c>a and c>d and c>e:
    n.insert(2,c)
elif d>b and d>c and d>a and d>e:
    n.insert(2,d)
elif e>b and e>c and e>d and e>a:
    n.insert(2,e)
if q1 == 6:
    if n[2] == f:
        f = int(-999)
if q1 == 6:
    if f>b and f>c and f>d and f>a:
        n.insert(2,f)
if n[2] == a:
    a = int(-999)
elif n[2] == b:
    b = int(-999)
elif n[2] == c:
    c = int(-999)
elif n[2] == d:
    d = int(-999)
elif n[2] == e:
    e = int(-999)
if q1 == 6:
    if n[2] == f:
        f = int(-999)
if a>b and a>c and a>d and a>e:
    n.insert(3,a)
elif b>a and b>c and b>d and b>e:
    n.insert(3,b)
elif c>b and c>a and c>d and c>e:
    n.insert(3,c)
elif d>b and d>c and d>a and d>e:
    n.insert(3,d)
elif e>b and e>c and e>d and e>a:
    n.insert(3,e)
if q1 == 6:
    if f>b and f>c and f>d and f>a:
          n.insert(3,f)
if n[3] == a:
    a = int(-999)
elif n[3] == b:
    b = int(-999)
elif n[3] == c:
    c = int(-999)
elif n[3] == d:
    d = int(-999)
elif n[3] == e:
    e = int(-999)
if q1 == 6:
    if n[3] == f:
        f = int(-999)
if a>b and a>c and a>d and a>e:
    n.insert(4,a)
elif b>a and b>c and b>d and b>e:
    n.insert(4,b)
elif c>b and c>a and c>d and c>e:
    n.insert(4,c)
elif d>b and d>c and d>a and d>e:
    n.insert(4,d)
elif e>b and e>c and e>d and e>a:
    n.insert(4,e)
if q1 == 6:
    if f>b and f>c and f>d and f>a:
         n.insert(4,f)
if n[4] == a:
    a = int(-999)
elif n[4] == b:
    b = int(-999)
elif n[4] == c:
    c = int(-999)
elif n[4] == d:
    d = int(-999)
elif n[4] == e:
    e = int(-999)
if q1 == 6:
    if n[4] == f:
        f = int(-999)
l=len(n)
check=l%2
if check == 0:
    if a>b and a>c and a>d and a>e:
        n.insert(5,a)
    elif b>a and b>c and b>d and b>e:
        n.insert(5,b)
    elif c>b and c>a and c>d and c>e:
        n.insert(5,c)
    elif d>b and d>c and d>a and d>e:
        n.insert(5,d)
    elif e>b and e>c and e>d and e>a:
        n.insert(5,e)
if q1 == 6:
    if f>b and f>c and f>d and f>a:
        n.insert(5,f)
    if n[5] == a:
        a = int(-999)
    elif n[5] == b:
        b = int(-999)
    elif n[5] == c:
        c = int(-999)
    elif n[5] == d:
        d = int(-999)
    elif n[5] == e:
        e = int(-999)
if q1 == 6:
    if n[5] == f:
        f = int(-999)

if check == 0:
    f1 = l/2
    f2 = l/2+1
    f1 = int(f1)
    f2 = int(f2)
    n1 = n[f1]
    n2 = n[f2]
    formula = (n1+n2)/2
    print("The median is: ",formula)
else:
    o=(len(n))/2
    x = int(o)
    print("The median is: ",n[x])
# Out:
# Number of elements? (5/6)5
# Enter 1st number: 11
# Enter 2nd number: 22
# Enter 3rd number: 33
# Enter 4th number: 44
# Enter 5th number: 55
# The median is:  33

# %% [markdown]
# x = 55.5
# s= x(float)
# print(x)

# %%
x=8
d = 8%2
print(d)
# Out:
# 0
